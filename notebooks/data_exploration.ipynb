# %% [markdown]
# # This is the official file for dataset exploration

# %%
from data.preprocess_har import HARPreprocessor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 from data.preprocess_har import HARPreprocessor
#
# ModuleNotFoundError: No module named 'data'

# %%
class_labels = {
    'calling': 0,
    'clapping': 1,
    'cycling': 2,
    'dancing': 3,
    'drinking': 4,
    'eating': 5,
    'fighting': 6,
    'hugging': 7,
    'laughing': 8,
    'listening_to_music': 9,
    'running': 10,
    'sitting': 11,
    'sleeping': 12,
    'texting': 13,
    'using_laptop': 14
}
labels_to_classes = {v: k for k, v in class_labels.items()}

# %%
print(f"total class labels are {len(class_labels)}")
print(f"total samples are {len(ds["train"])}")
sample = ds["train"][3]
print(f"The Person in the image is {labels_to_classes[sample['labels']]}")
sample["image"]
# Out:
# total class labels are 15
# total samples are 12600
# The Person in the image is sleeping
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>
